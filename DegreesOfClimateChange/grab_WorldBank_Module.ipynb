# %% [markdown]
# ## World Bank Module
# **Table of Contents**
# 1. Set up data connection with world bank climate api using _wbpy_ library. Note: country_codes is list of ISO codes used by the world bank and are 'keys' to its database
# 2. How is data being stored? Preliminary processing. Naive implementation of grab_worldbank()
# 3. Final version of grab_worldbank()
# 4. Example uses
#
# **Note: NEED to install wbpy <------- **
# - wbpy: https://github.com/mattduck/wbpy.
#     * _not an official Python library for the world bank, but is well documented/used, and handles all the intricacies of interfacing with the World Bank RESTFUL API.
#     * Our project will appropriately unittest any and all functions incorporating the wbpy library.
#
# **Functions grab_worldbank() and test_output_grab_worldbank() also stored in grab_worldbank.py**

# %% [markdown]
# ## 1 & 2

# %%
import wbpy
import pandas as pd
import sys

country_codes = pd.read_csv('country_iso_codes.csv')['CODE'].dropna()
climate_api = wbpy.ClimateAPI()

# %%
def grab_worldbank():
    """
    Function handle to return pointer to worldbank dataset for all countries
    
    Arguments:
    -Currently None
    
    Returns:
    - dict:
    
    """
    climate_api = wbpy.ClimateAPI()
    country_codes = pd.read_csv('country_iso_codes.csv')['CODE'].dropna()
    dataset = {}
    for code in country_codes: 
        try:       
            dataset[code]=climate_api.get_instrumental(data_type='tas',interval='year',locations=[code])
        except Exception as e: 
            print("Encountered Error Getting Data for Code: {}".format(code))
            continue
    return dataset

# %%
#Run it 
wb_data = grab_worldbank()
print(type(wb_data))
# Out:
# <class 'dict'>

# %% [markdown]
# Let's see how we can use the wb_data dict variable...

# %%
for key in wb_data.keys():
    country_data = wb_data[key].as_dict()[key]
    print("Temperature Data for {}".format(key))
    for year_key in country_data.keys():
        print("...{} has temperature value of {} C".format(year_key, country_data[year_key]))
    break #so we don't output the whole dataset...
# Out:
# Temperature Data for AFG
# ...1901 has temperature value of 13.096678 C
# ...1902 has temperature value of 13.309858 C
# ...1903 has temperature value of 12.064352 C
# ...1904 has temperature value of 12.619226 C
# ...1905 has temperature value of 12.437119 C
# ...1906 has temperature value of 12.978949 C
# ...1907 has temperature value of 12.276689 C
# ...1908 has temperature value of 12.527205 C
# ...1909 has temperature value of 12.797849 C
# ...1910 has temperature value of 12.057898 C
# ...1911 has temperature value of 12.295179 C
# ...1912 has temperature value of 12.9023695 C
# ...1913 has temperature value of 12.642592 C
# ...1914 has temperature value of 13.308415 C
# ...1915 has temperature value of 13.922549 C
# ...1916 has temperature value of 12.5204525 C
# ...1917 has temperature value of 13.175219 C
# ...1918 has temperature value of 11.86811 C
# ...1919 has temperature value of 12.038753 C
# ...1920 has temperature value of 11.508769 C
# ...1921 has temperature value of 12.502941 C
# ...1922 has temperature value of 12.974073 C
# ...1923 has temperature value of 11.935648 C
# ...1924 has temperature value of 12.171977 C
# ...1925 has temperature value of 12.666531 C
# ...1926 has temperature value of 12.733714 C
# ...1927 has temperature value of 12.74055 C
# ...1928 has temperature value of 12.42903 C
# ...1929 has temperature value of 12.05896 C
# ...1930 has temperature value of 12.016857 C
# ...1931 has temperature value of 12.070452 C
# ...1932 has temperature value of 12.387337 C
# ...1933 has temperature value of 12.473448 C
# ...1934 has temperature value of 11.963971 C
# ...1935 has temperature value of 11.976525 C
# ...1936 has temperature value of 12.653677 C
# ...1937 has temperature value of 12.071296 C
# ...1938 has temperature value of 12.760702 C
# ...1939 has temperature value of 12.860594 C
# ...1940 has temperature value of 13.448639 C
# ...1941 has temperature value of 14.052069 C
# ...1942 has temperature value of 13.079549 C
# ...1943 has temperature value of 12.422548 C
# ...1944 has temperature value of 13.028513 C
# ...1945 has temperature value of 12.348366 C
# ...1946 has temperature value of 13.111139 C
# ...1947 has temperature value of 13.688725 C
# ...1948 has temperature value of 12.964951 C
# ...1949 has temperature value of 11.965741 C
# ...1950 has temperature value of 11.52146 C
# ...1951 has temperature value of 12.672467 C
# ...1952 has temperature value of 12.815332 C
# ...1953 has temperature value of 13.340495 C
# ...1954 has temperature value of 12.314188 C
# ...1955 has temperature value of 13.218355 C
# ...1956 has temperature value of 12.726471 C
# ...1957 has temperature value of 11.457108 C
# ...1958 has temperature value of 13.281781 C
# ...1959 has temperature value of 12.710267 C
# ...1960 has temperature value of 12.427369 C
# ...1961 has temperature value of 12.881208 C
# ...1962 has temperature value of 12.499809 C
# ...1963 has temperature value of 13.515714 C
# ...1964 has temperature value of 11.882081 C
# ...1965 has temperature value of 12.775789 C
# ...1966 has temperature value of 13.063208 C
# ...1967 has temperature value of 12.516421 C
# ...1968 has temperature value of 12.444172 C
# ...1969 has temperature value of 12.364134 C
# ...1970 has temperature value of 13.470589 C
# ...1971 has temperature value of 13.594363 C
# ...1972 has temperature value of 11.218818 C
# ...1973 has temperature value of 12.871515 C
# ...1974 has temperature value of 12.071978 C
# ...1975 has temperature value of 12.195915 C
# ...1976 has temperature value of 12.503267 C
# ...1977 has temperature value of 13.542892 C
# ...1978 has temperature value of 13.097303 C
# ...1979 has temperature value of 12.992266 C
# ...1980 has temperature value of 13.331482 C
# ...1981 has temperature value of 13.356209 C
# ...1982 has temperature value of 12.302015 C
# ...1983 has temperature value of 13.343791 C
# ...1984 has temperature value of 12.90531 C
# ...1985 has temperature value of 13.397577 C
# ...1986 has temperature value of 12.7904415 C
# ...1987 has temperature value of 13.479494 C
# ...1988 has temperature value of 14.105202 C
# ...1989 has temperature value of 12.698202 C
# ...1990 has temperature value of 13.576281 C
# ...1991 has temperature value of 13.151906 C
# ...1992 has temperature value of 12.627124 C
# ...1993 has temperature value of 12.980337 C
# ...1994 has temperature value of 13.100027 C
# ...1995 has temperature value of 13.025299 C
# ...1996 has temperature value of 12.583796 C
# ...1997 has temperature value of 12.90226 C
# ...1998 has temperature value of 13.209804 C
# ...1999 has temperature value of 14.076879 C
# ...2000 has temperature value of 13.710948 C
# ...2001 has temperature value of 14.407163 C
# ...2002 has temperature value of 14.278839 C
# ...2003 has temperature value of 13.816203 C
# ...2004 has temperature value of 14.669527 C
# ...2005 has temperature value of 14.107597 C
# ...2006 has temperature value of 14.277315 C
# ...2007 has temperature value of 14.124646 C
# ...2008 has temperature value of 14.249019 C
# ...2009 has temperature value of 14.222303 C
# ...2010 has temperature value of 14.189791 C
# ...2011 has temperature value of 13.727007 C
# ...2012 has temperature value of 13.095462 C

# %% [markdown]
# ## 3. Convert above data retrieval mechanism to Python function form, expanding on former function grab_worldbank()

# %%
def grab_worldbank(select_countries=None, start_date = None, end_date = None):
    import wbpy
    import pandas as pd
    import sys
    import numpy as np


    """
    ################ FIX THIS DOCSTRING #####################
    
    Arguments:
        select_countries (list): List of countries from which to obtain temperature data. 
                                Default 'None' means obtain from all countries
        start_date (int): Starting date in yyyy integer format for the historical data. 
                          Default 'None' means 1901, the earliest available year on the World Bank dataset
        end_date (int): Ending date in yyyy integer format. Default 'None' means 2015. 
    
    Returns:
    - Pandas DataFrame:
    
    """
    
    """Argument/type checking"""
    if (  (select_countries is not None and not isinstance(select_countries,list)) or 
          (start_date is not None and not isinstance(start_date,int)) or 
           (end_date is not None and not isinstance(end_date, int))
        ) :
        raise ValueError("Error: Arguments are of incorrect datatype!")
    
    
    if (end_date is not None and end_date > 2015): 
        raise ValueError("Error: Starting date cannot exceed 2015")
        
    if (start_date is None):
        start_date = 1901
    if (end_date is None):
        end_date = 2015
    
    """Dictionary to store countries who do NOT HAVE DATA"""
    err_dict = {}
    
    """Instantiate API Interface using wbpy package"""
    climate_api = wbpy.ClimateAPI()
    
    """Read in country codes from World Bank website"""
    iso_codes_df = pd.read_csv('country_iso_codes.csv').dropna()
    codes_list = np.array(iso_codes_df['CODE'])
    country_list = np.array(iso_codes_df['COUNTRY'])

    
    """Run data collections"""
    if (select_countries is not None):
        try: 
            code_country_pairs = [(country_list[k],codes_list[k]) for k in range(0,len(codes_list)) if country_list[k] in select_countries]
            #country_codes = iso_codes_df['CODE']
        except Exception as e:
            print(e)
            sys.exit(0)
    else: 
        code_country_pairs = [(country_list[k],codes_list[k]) for k in range(0,len(codes_list))]
    data_len = len(code_country_pairs)
    dataset = {}
    for k in range(0,data_len):
        code = code_country_pairs[k][1]
        try:       
            dataset[code]=climate_api.get_instrumental(data_type='tas',interval='year',locations=[code])
        except Exception as e: 
            print("Warning: Data Does Not Exist for Country Code: {}".format(code))
            # Add erroneous country to error dictionary
            err_dict[code] = 1
            continue
    
    """Create pandas dataframe of the data"""
    
    df = pd.DataFrame(columns=['Country','Code','Year','Temperature'])
    
    count = 0
    for k in range(0,data_len):
        c_name,c_code = code_country_pairs[k][0], code_country_pairs[k][1]
        if (c_code not in err_dict): 
            country_data = dataset[c_code].as_dict()[c_code]
            for year_key in country_data.keys():
                if (int(year_key) >= start_date and int(year_key) <= end_date):
                    df.loc[count] = [c_name, c_code,year_key, country_data[year_key]]
                    count += 1
    return df

# %% [markdown]
# ## 4. Example Usage

# %%
def test_output_grab_worldbank():
    """Get all data for only United States"""
    print("Get all data for only United States")
    select = ['United States']
    wb_data_df = grab_worldbank(select_countries=select)
    print(wb_data_df.head(30))
    print("------------------------------------------------------------")

    """Get all data for only United States, Burkina Faso, and Georgia"""
    print("Get all data for only United States, Burkina Faso, and Georgia")
    select = ['United States','Burkina Faso', 'Georgia']
    wb_data_df = grab_worldbank(select_countries=select)
    print(wb_data_df.head(30))
    print("------------------------------------------------------------")

    """Get only year 2000-ending date data for only United States, Burkina Faso, and Georgia"""
    print("Get only year 2000-ending date data for only United States, Burkina Faso, and Georgia")
    select = ['United States','Burkina Faso', 'Georgia']
    wb_data_df = grab_worldbank(select_countries=select, start_date = 2000)
    print(wb_data_df.head(30))
    print("------------------------------------------------------------")

    """Get only 1910-1915 date data for only United States, Burkina Faso, and Georgia"""
    print("Get only 1910-1915 date data for only United States, Burkina Faso, and Georgia")
    select = ['United States','Burkina Faso', 'Georgia']
    wb_data_df = grab_worldbank(select_countries=select, start_date = 1910, end_date=1915)
    print(wb_data_df.head(30))
    print("------------------------------------------------------------")

    """Get all data for all countries"""
    print("Get all data for all countries")
    wb_data_df = grab_worldbank()
    print(wb_data_df.tail(20))
    print("------------------------------------------------------------")

# %%
test_output_grab_worldbank()
# Out:
# Get all data for only United States
#           Country Code  Year  Temperature
# 0   United States  USA  1901     6.618749
# 1   United States  USA  1902     6.464327
# 2   United States  USA  1903     6.073844
# 3   United States  USA  1904     6.149883
# 4   United States  USA  1905     6.599617
# 5   United States  USA  1906     6.522858
# 6   United States  USA  1907     6.326528
# 7   United States  USA  1908     6.698544
# 8   United States  USA  1909     6.037902
# 9   United States  USA  1910     6.572676
# 10  United States  USA  1911     6.600330
# 11  United States  USA  1912     6.377984
# 12  United States  USA  1913     6.598086
# 13  United States  USA  1914     6.960702
# 14  United States  USA  1915     6.805295
# 15  United States  USA  1916     6.159147
# 16  United States  USA  1917     5.670571
# 17  United States  USA  1918     6.365317
# 18  United States  USA  1919     6.488107
# 19  United States  USA  1920     6.091616
# 20  United States  USA  1921     7.385264
# 21  United States  USA  1922     6.656533
# 22  United States  USA  1923     6.807252
# 23  United States  USA  1924     6.048655
# 24  United States  USA  1925     6.943725
# 25  United States  USA  1926     7.315650
# 26  United States  USA  1927     6.566365
# 27  United States  USA  1928     6.933179
# 28  United States  USA  1929     6.571394
# 29  United States  USA  1930     6.689477
# ------------------------------------------------------------
# Get all data for only United States, Burkina Faso, and Georgia
#          Country Code  Year  Temperature
# 0   Burkina Faso  BFA  1901    27.678238
# 1   Burkina Faso  BFA  1902    27.913498
# 2   Burkina Faso  BFA  1903    28.122864
# 3   Burkina Faso  BFA  1904    28.234299
# 4   Burkina Faso  BFA  1905    27.813152
# 5   Burkina Faso  BFA  1906    28.325893
# 6   Burkina Faso  BFA  1907    28.177067
# 7   Burkina Faso  BFA  1908    28.186707
# 8   Burkina Faso  BFA  1909    28.094350
# 9   Burkina Faso  BFA  1910    28.379477
# 10  Burkina Faso  BFA  1911    27.739462
# 11  Burkina Faso  BFA  1912    28.264187
# 12  Burkina Faso  BFA  1913    28.397380
# 13  Burkina Faso  BFA  1914    28.424381
# 14  Burkina Faso  BFA  1915    27.541529
# 15  Burkina Faso  BFA  1916    27.039944
# 16  Burkina Faso  BFA  1917    27.266804
# 17  Burkina Faso  BFA  1918    27.069834
# 18  Burkina Faso  BFA  1919    28.220112
# 19  Burkina Faso  BFA  1920    28.237950
# 20  Burkina Faso  BFA  1921    28.228582
# 21  Burkina Faso  BFA  1922    27.740360
# 22  Burkina Faso  BFA  1923    27.514532
# 23  Burkina Faso  BFA  1924    28.195730
# 24  Burkina Faso  BFA  1925    27.771969
# 25  Burkina Faso  BFA  1926    28.094076
# 26  Burkina Faso  BFA  1927    27.323486
# 27  Burkina Faso  BFA  1928    27.162120
# 28  Burkina Faso  BFA  1929    27.391254
# 29  Burkina Faso  BFA  1930    27.922934
# ------------------------------------------------------------
# Get only year 2000-ending date data for only United States, Burkina Faso, and Georgia
#           Country Code  Year  Temperature
# 0    Burkina Faso  BFA  2000    28.542286
# 1    Burkina Faso  BFA  2001    28.575481
# 2    Burkina Faso  BFA  2002    28.913294
# 3    Burkina Faso  BFA  2003    28.801239
# 4    Burkina Faso  BFA  2004    28.889395
# 5    Burkina Faso  BFA  2005    29.163086
# 6    Burkina Faso  BFA  2006    28.708817
# 7    Burkina Faso  BFA  2007    28.889118
# 8    Burkina Faso  BFA  2008    28.336914
# 9    Burkina Faso  BFA  2009    29.009710
# 10   Burkina Faso  BFA  2010    29.235912
# 11   Burkina Faso  BFA  2011    29.005215
# 12   Burkina Faso  BFA  2012    28.664463
# 13        Georgia  GEO  2000     6.855065
# 14        Georgia  GEO  2001     7.405719
# 15        Georgia  GEO  2002     6.621242
# 16        Georgia  GEO  2003     6.239542
# 17        Georgia  GEO  2004     7.037418
# 18        Georgia  GEO  2005     6.938072
# 19        Georgia  GEO  2006     6.663072
# 20        Georgia  GEO  2007     7.091503
# 21        Georgia  GEO  2008     6.864706
# 22        Georgia  GEO  2009     7.017157
# 23        Georgia  GEO  2010     8.946199
# 24        Georgia  GEO  2011     6.723977
# 25        Georgia  GEO  2012     7.815205
# 26  United States  USA  2000     7.431657
# 27  United States  USA  2001     7.572003
# 28  United States  USA  2002     7.750373
# 29  United States  USA  2003     7.688549
# ------------------------------------------------------------
# Get only 1910-1915 date data for only United States, Burkina Faso, and Georgia
#           Country Code  Year  Temperature
# 0    Burkina Faso  BFA  1910    28.379477
# 1    Burkina Faso  BFA  1911    27.739462
# 2    Burkina Faso  BFA  1912    28.264187
# 3    Burkina Faso  BFA  1913    28.397380
# 4    Burkina Faso  BFA  1914    28.424381
# 5    Burkina Faso  BFA  1915    27.541529
# 6         Georgia  GEO  1910     6.219771
# 7         Georgia  GEO  1911     4.436601
# 8         Georgia  GEO  1912     6.116340
# 9         Georgia  GEO  1913     5.431209
# 10        Georgia  GEO  1914     6.064542
# 11        Georgia  GEO  1915     6.470588
# 12  United States  USA  1910     6.572676
# 13  United States  USA  1911     6.600330
# 14  United States  USA  1912     6.377984
# 15  United States  USA  1913     6.598086
# 16  United States  USA  1914     6.960702
# 17  United States  USA  1915     6.805295
# ------------------------------------------------------------
# Get all data for all countries
# Warning: Data Does Not Exist for Country Code: CHI
# Warning: Data Does Not Exist for Country Code: KSV
# Warning: Data Does Not Exist for Country Code: ARB
# Warning: Data Does Not Exist for Country Code: CSS
# Warning: Data Does Not Exist for Country Code: EAS
# Warning: Data Does Not Exist for Country Code: EAP
# Warning: Data Does Not Exist for Country Code: EMU
# Warning: Data Does Not Exist for Country Code: ECS
# Warning: Data Does Not Exist for Country Code: ECA
# Warning: Data Does Not Exist for Country Code: EUU
# Warning: Data Does Not Exist for Country Code: HPC
# Warning: Data Does Not Exist for Country Code: HIC
# Warning: Data Does Not Exist for Country Code: LCN
# Warning: Data Does Not Exist for Country Code: LAC
# Warning: Data Does Not Exist for Country Code: LDC
# Warning: Data Does Not Exist for Country Code: LMY
# Warning: Data Does Not Exist for Country Code: LIC
# Warning: Data Does Not Exist for Country Code: LMC
# Warning: Data Does Not Exist for Country Code: MEA
# Warning: Data Does Not Exist for Country Code: MNA
# Warning: Data Does Not Exist for Country Code: MIC
# Warning: Data Does Not Exist for Country Code: NAC
# Warning: Data Does Not Exist for Country Code: OED
# Warning: Data Does Not Exist for Country Code: OSS
# Warning: Data Does Not Exist for Country Code: PSS
# Warning: Data Does Not Exist for Country Code: SST
# Warning: Data Does Not Exist for Country Code: SAS
# Warning: Data Does Not Exist for Country Code: SSF
# Warning: Data Does Not Exist for Country Code: SSA
# Warning: Data Does Not Exist for Country Code: UMC
# Warning: Data Does Not Exist for Country Code: WLD
